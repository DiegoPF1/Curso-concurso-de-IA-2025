# %%
import cv2 #Cargar OpenCV
import matplotlib.pyplot as plt #Para visualizar. 
                                #En local usar directamente 
                                #imshow

# %%
ruta_imagen = 'imagenes/r2d2_urdf.png' #ruta a la imagen

# %%
imagen_bgr = cv2.imread(ruta_imagen)   #carga la imagen

# %%
#Convierte
imagen_rgb = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB) 
plt.imshow(imagen_rgb)
plt.title('Imagen RD2D2')  # Título opcional
plt.axis('off')  # Ocultar ejes
plt.show()
